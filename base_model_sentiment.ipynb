# %%
# https://www.youtube.com/watch?v=CbTU92pbDKw

# %%
import yfinance as yf
import pandas as pd

ticker = "GLD"
gold_data = yf.download(
    ticker,
    start="2000-01-01",
    end=None,
    progress=False,
    auto_adjust=False,
    actions=True,
)
gold_data
# Out:
# Price        Adj Close Capital Gains       Close Dividends        High  \
# Ticker             GLD           GLD         GLD       GLD         GLD
# Date
# 2004-11-18   44.380001           0.0   44.380001       0.0   44.490002
# 2004-11-19   44.779999           0.0   44.779999       0.0   44.919998
# 2004-11-22   44.950001           0.0   44.950001       0.0   44.970001
# 2004-11-23   44.750000           0.0   44.750000       0.0   44.919998
# 2004-11-24   45.049999           0.0   45.049999       0.0   45.049999
# ...                ...           ...         ...       ...         ...
# 2025-04-22  311.109985           0.0  311.109985       0.0  317.630005
# 2025-04-23  303.649994           0.0  303.649994       0.0  304.739990
# 2025-04-24  308.070007           0.0  308.070007       0.0  308.500000
# 2025-04-25  304.730011           0.0  304.730011       0.0  305.369995
# 2025-04-28  309.070007           0.0  309.070007       0.0  309.109985
#
# Price              Low        Open Stock Splits    Volume
# Ticker             GLD         GLD          GLD       GLD
# Date
# 2004-11-18   44.070000   44.430000          0.0   5992000
# 2004-11-19   44.470001   44.490002          0.0  11655300
# 2004-11-22   44.740002   44.750000          0.0  11996000
# 2004-11-23   44.720001   44.880001          0.0   3169200
# 2004-11-24   44.790001   44.930000          0.0   6105100
# ...                ...         ...          ...       ...
# 2025-04-22  310.359985  317.489990          0.0  35242300
# 2025-04-23  300.589996  304.179993          0.0  25421500
# 2025-04-24  304.709991  306.980011          0.0  10845000
# 2025-04-25  301.010010  301.779999          0.0  10609100
# 2025-04-28  302.970001  304.149994          0.0   9235537
#
# [5142 rows x 9 columns]

# %%
finbert_score = pd.read_csv("Final_sentiment_score.csv")
finbert_score = finbert_score[["Date", "Positive", "Neutral", "Negative"]]
finbert_score["sentiment"] = finbert_score["Positive"] - finbert_score["Negative"]

# %%
finbert_score
# Out:
#             Date  Positive   Neutral  Negative  sentiment
# 0     2000-02-15  0.398276  0.585515  0.016209   0.382066
# 1     2000-02-17  0.077722  0.095735  0.826543  -0.748821
# 2     2000-03-24  0.180700  0.287722  0.531578  -0.350879
# 3     2000-04-27  0.393267  0.346374  0.260358   0.132909
# 4     2000-05-04  0.337279  0.255016  0.407705  -0.070426
# ...          ...       ...       ...       ...        ...
# 3667  2019-01-25  0.786646  0.120372  0.092982   0.693664
# 3668  2019-01-28  0.749922  0.169181  0.080897   0.669025
# 3669  2019-01-30  0.790114  0.135270  0.074616   0.715498
# 3670  2019-01-31  0.128171  0.481111  0.390717  -0.262546
# 3671  2019-02-01  0.080484  0.883677  0.035839   0.044645
#
# [3672 rows x 5 columns]

# %%
finbert_score["Date"] = pd.to_datetime(finbert_score["Date"])

# %%
gold_data.reset_index(inplace=True)
gold_data.columns = [col[0] for col in gold_data.columns]

gold_data["Date"] = pd.to_datetime(gold_data["Date"])

# %%
merged_df = pd.merge(
    finbert_score, gold_data, left_on="Date", right_on="Date", how="inner"
)

# %%
df = merged_df[["Date", "Open", "sentiment"]]

df
# Out:
#            Date        Open  sentiment
# 0    2004-11-18   44.430000  -0.579322
# 1    2004-11-19   44.490002   0.726477
# 2    2004-11-22   44.750000   0.347871
# 3    2004-11-23   44.880001  -0.801077
# 4    2004-11-24   44.930000   0.892562
# ...         ...         ...        ...
# 2914 2019-01-25  122.019997   0.693664
# 2915 2019-01-28  122.750000   0.669025
# 2916 2019-01-30  123.910004   0.715498
# 2917 2019-01-31  125.180000  -0.262546
# 2918 2019-02-01  124.889999   0.044645
#
# [2919 rows x 3 columns]

# %%
# make date the index
df.index = df.pop("Date")
df
# Out:
#                   Open  sentiment
# Date
# 2004-11-18   44.430000  -0.579322
# 2004-11-19   44.490002   0.726477
# 2004-11-22   44.750000   0.347871
# 2004-11-23   44.880001  -0.801077
# 2004-11-24   44.930000   0.892562
# ...                ...        ...
# 2019-01-25  122.019997   0.693664
# 2019-01-28  122.750000   0.669025
# 2019-01-30  123.910004   0.715498
# 2019-01-31  125.180000  -0.262546
# 2019-02-01  124.889999   0.044645
#
# [2919 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df["Open"])

# %%
import numpy as np


def df_to_windowed_df(dataframe, n=3):
    dates = []
    X, Y = [], []

    for i in range(n, len(dataframe)):
        window = dataframe.iloc[i - n : i + 1]  # n previous + 1 target row

        if len(window) != n + 1:
            continue  # skip if not enough data

        values = window[["Open", "sentiment"]].to_numpy()
        x, y = values[:-1], values[-1][0]

        dates.append(dataframe.index[i])  # the date corresponding to the target
        X.append(x)
        Y.append(y)

    ret_df = pd.DataFrame({"Target Date": dates})

    X = np.array(X)
    for i in range(n):
        ret_df[f"Target-{n - i}"] = list(
            X[:, i]
        )  # each element is a pair: [Close, sentiment]

    ret_df["Target"] = Y

    return ret_df

# %%
windowed_df = df_to_windowed_df(df, n=3)
windowed_df
# Out:
#      Target Date                                   Target-3  \
# 0     2004-11-23   [44.43000030517578, -0.5793219208717346]
# 1     2004-11-24     [44.4900016784668, 0.7264769300818444]
# 2     2004-11-29                [44.75, 0.3478713557124139]
# 3     2004-11-30  [44.880001068115234, -0.8010769858956337]
# 4     2004-12-01    [44.93000030517578, 0.8925615362823012]
# ...          ...                                        ...
# 2911  2019-01-25   [122.27999877929688, 0.8107122350484133]
# 2912  2019-01-28   [120.95999908447266, 0.8944073989987373]
# 2913  2019-01-30  [121.16000366210938, -0.6877921521663666]
# 2914  2019-01-31    [122.0199966430664, 0.6936637610197068]
# 2915  2019-02-01               [122.75, 0.6690251007676125]
#
#                                        Target-2  \
# 0        [44.4900016784668, 0.7264769300818444]
# 1                   [44.75, 0.3478713557124139]
# 2     [44.880001068115234, -0.8010769858956337]
# 3       [44.93000030517578, 0.8925615362823012]
# 4      [45.099998474121094, 0.0849677324295044]
# ...                                         ...
# 2911   [120.95999908447266, 0.8944073989987373]
# 2912  [121.16000366210938, -0.6877921521663666]
# 2913    [122.0199966430664, 0.6936637610197068]
# 2914               [122.75, 0.6690251007676125]
# 2915   [123.91000366210938, 0.7154975235462189]
#
#                                         Target-1      Target
# 0                    [44.75, 0.3478713557124139]   44.880001
# 1      [44.880001068115234, -0.8010769858956337]   44.930000
# 2        [44.93000030517578, 0.8925615362823012]   45.099998
# 3       [45.099998474121094, 0.0849677324295044]   45.369999
# 4      [45.369998931884766, -0.8006784543395044]   45.279999
# ...                                          ...         ...
# 2911   [121.16000366210938, -0.6877921521663666]  122.019997
# 2912     [122.0199966430664, 0.6936637610197068]  122.750000
# 2913                [122.75, 0.6690251007676125]  123.910004
# 2914    [123.91000366210938, 0.7154975235462189]  125.180000
# 2915  [125.18000030517578, -0.26254571974277496]  124.889999
#
# [2916 rows x 5 columns]

# %%
df
# Out:
#                   Open  sentiment
# Date
# 2004-11-18   44.430000  -0.579322
# 2004-11-19   44.490002   0.726477
# 2004-11-22   44.750000   0.347871
# 2004-11-23   44.880001  -0.801077
# 2004-11-24   44.930000   0.892562
# ...                ...        ...
# 2019-01-25  122.019997   0.693664
# 2019-01-28  122.750000   0.669025
# 2019-01-30  123.910004   0.715498
# 2019-01-31  125.180000  -0.262546
# 2019-02-01  124.889999   0.044645
#
# [2919 rows x 2 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
    dates = windowed_dataframe["Target Date"].to_numpy()

    feature_cols = windowed_dataframe.columns[1:-1]

    X = []
    for _, row in windowed_dataframe[feature_cols].iterrows():
        # Each val is a [Close, Sentiment] pair
        values = [val for val in row]  # Keep as 2D structure
        X.append(values)

    X = np.array(X)  # Shape will be (num_rows, n, 2)
    Y = windowed_dataframe["Target"].to_numpy()

    return dates, X.astype(np.float32), Y.astype(np.float32)


dates, X, y = windowed_df_to_date_X_y(windowed_df)

# check all the shapes
dates.shape, X.shape, y.shape
# Out:
# ((2916,), (2916, 3, 2), (2916,))

# %%
# training part
q_75 = int(len(dates) * 0.75)

# validation part
q_85 = int(len(dates) * 0.85)

# testing part
q_95 = int(len(dates) * 0.95)

dates_train, X_train, y_train = dates[:q_75], X[:q_75], y[:q_75]
dates_val, X_val, y_val = dates[q_75:q_85], X[q_75:q_85], y[q_75:q_85]
dates_test, X_test, y_test = dates[q_85:q_95], X[q_85:q_95], y[q_85:q_95]
dates_hold, X_hold, y_hold = dates[q_95:], X[q_95:], y[q_95:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(["Train", "Validation", "Test"])
plt.xlabel("Date")
plt.ylabel("Target Value")
plt.title("Train / Validation / Test Split")
plt.show()

# %%
X_train
# Out:
# array([[[ 44.43      ,  -0.5793219 ],
#         [ 44.49      ,   0.7264769 ],
#         [ 44.75      ,   0.34787136]],
#
#        [[ 44.49      ,   0.7264769 ],
#         [ 44.75      ,   0.34787136],
#         [ 44.88      ,  -0.801077  ]],
#
#        [[ 44.75      ,   0.34787136],
#         [ 44.88      ,  -0.801077  ],
#         [ 44.93      ,   0.89256155]],
#
#        ...,
#
#        [[105.76      ,   0.5046343 ],
#         [106.32      ,   0.45507243],
#         [106.86      ,   0.57726234]],
#
#        [[106.32      ,   0.45507243],
#         [106.86      ,   0.57726234],
#         [106.55      ,  -0.29270324]],
#
#        [[106.86      ,   0.57726234],
#         [106.55      ,  -0.29270324],
#         [106.61      ,   0.37641606]]], dtype=float32)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential(
    [
        layers.Input((3, 2)),  # window size = 3, feature = 2
        layers.LSTM(64),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(1),
    ]
)  # since the output we want is just 1

model.compile(
    loss="mse", optimizer=Adam(learning_rate=0.001), metrics=["mean_absolute_error"]
)

model.fit(
    X_train, y_train, validation_data=(X_val, y_val), epochs=100
)  # 100 runs through the dataset
# Out:
# Epoch 1/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 12486.7354 - mean_absolute_error: 105.2799 - val_loss: 7654.8945 - val_mean_absolute_error: 87.3079
# Epoch 2/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4159.3477 - mean_absolute_error: 52.6427 - val_loss: 93.9111 - val_mean_absolute_error: 8.4849
# Epoch 3/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 541.6114 - mean_absolute_error: 16.2876 - val_loss: 22.2434 - val_mean_absolute_error: 4.4270
# Epoch 4/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13.6822 - mean_absolute_error: 2.3396 - val_loss: 2.5427 - val_mean_absolute_error: 1.2652
# Epoch 5/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.9396 - mean_absolute_error: 1.5532 - val_loss: 1.4544 - val_mean_absolute_error: 0.8827
# Epoch 6/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6302 - mean_absolute_error: 1.2771 - val_loss: 1.4703 - val_mean_absolute_error: 0.8831
# Epoch 7/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2345 - mean_absolute_error: 1.2623 - val_loss: 3.9714 - val_mean_absolute_error: 1.6845
# Epoch 8/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4041 - mean_absolute_error: 1.3175 - val_loss: 2.4193 - val_mean_absolute_error: 1.2301
# Epoch 9/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4029 - mean_absolute_error: 1.3384 - val_loss: 1.5697 - val_mean_absolute_error: 0.9436
# Epoch 10/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2022 - mean_absolute_error: 1.3127 - val_loss: 1.4331 - val_mean_absolute_error: 0.8834
# Epoch 11/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3840 - mean_absolute_error: 1.3450 - val_loss: 2.2343 - val_mean_absolute_error: 1.1695
# Epoch 12/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8639 - mean_absolute_error: 1.2361 - val_loss: 1.5867 - val_mean_absolute_error: 0.9334
# Epoch 13/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5738 - mean_absolute_error: 1.1613 - val_loss: 1.7979 - val_mean_absolute_error: 1.0333
# Epoch 14/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4843 - mean_absolute_error: 1.5926 - val_loss: 1.4828 - val_mean_absolute_error: 0.9033
# Epoch 15/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5226 - mean_absolute_error: 1.4183 - val_loss: 2.1080 - val_mean_absolute_error: 1.1266
# Epoch 16/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0565 - mean_absolute_error: 1.2495 - val_loss: 1.7149 - val_mean_absolute_error: 1.0180
# Epoch 17/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2386 - mean_absolute_error: 1.2147 - val_loss: 1.7399 - val_mean_absolute_error: 0.9870
# Epoch 18/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4581 - mean_absolute_error: 1.1279 - val_loss: 1.4662 - val_mean_absolute_error: 0.8903
# Epoch 19/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8895 - mean_absolute_error: 1.2342 - val_loss: 1.7234 - val_mean_absolute_error: 0.9802
# Epoch 20/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9734 - mean_absolute_error: 1.2511 - val_loss: 1.8108 - val_mean_absolute_error: 1.0139
# Epoch 21/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5061 - mean_absolute_error: 1.1425 - val_loss: 2.3111 - val_mean_absolute_error: 1.1952
# Epoch 22/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6904 - mean_absolute_error: 1.1832 - val_loss: 1.4266 - val_mean_absolute_error: 0.8860
# Epoch 23/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8794 - mean_absolute_error: 1.2158 - val_loss: 2.9976 - val_mean_absolute_error: 1.4504
# Epoch 24/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9214 - mean_absolute_error: 1.2420 - val_loss: 2.0256 - val_mean_absolute_error: 1.0896
# Epoch 25/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0008 - mean_absolute_error: 1.2644 - val_loss: 6.2150 - val_mean_absolute_error: 2.2085
# Epoch 26/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6194 - mean_absolute_error: 1.4819 - val_loss: 1.5221 - val_mean_absolute_error: 0.9331
# Epoch 27/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6015 - mean_absolute_error: 1.1748 - val_loss: 1.7154 - val_mean_absolute_error: 0.9786
# Epoch 28/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9275 - mean_absolute_error: 1.2311 - val_loss: 1.4363 - val_mean_absolute_error: 0.8779
# Epoch 29/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7198 - mean_absolute_error: 1.1824 - val_loss: 2.1156 - val_mean_absolute_error: 1.1214
# Epoch 30/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4700 - mean_absolute_error: 1.1501 - val_loss: 1.5254 - val_mean_absolute_error: 0.9028
# Epoch 31/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4941 - mean_absolute_error: 1.1440 - val_loss: 2.0951 - val_mean_absolute_error: 1.1135
# Epoch 32/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6490 - mean_absolute_error: 1.1725 - val_loss: 1.8018 - val_mean_absolute_error: 1.0023
# Epoch 33/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8251 - mean_absolute_error: 1.2202 - val_loss: 1.5784 - val_mean_absolute_error: 0.9539
# Epoch 34/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6629 - mean_absolute_error: 1.1884 - val_loss: 2.1468 - val_mean_absolute_error: 1.1551
# Epoch 35/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6621 - mean_absolute_error: 1.1762 - val_loss: 1.6199 - val_mean_absolute_error: 0.9801
# Epoch 36/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6955 - mean_absolute_error: 1.2043 - val_loss: 3.3530 - val_mean_absolute_error: 1.5144
# Epoch 37/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0920 - mean_absolute_error: 1.2918 - val_loss: 1.7083 - val_mean_absolute_error: 0.9758
# Epoch 38/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8007 - mean_absolute_error: 1.2499 - val_loss: 2.1611 - val_mean_absolute_error: 1.1448
# Epoch 39/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1797 - mean_absolute_error: 1.3043 - val_loss: 1.4767 - val_mean_absolute_error: 0.9066
# Epoch 40/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8480 - mean_absolute_error: 1.2531 - val_loss: 2.2304 - val_mean_absolute_error: 1.1636
# Epoch 41/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7113 - mean_absolute_error: 1.2095 - val_loss: 1.6649 - val_mean_absolute_error: 0.9857
# Epoch 42/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0801 - mean_absolute_error: 1.2813 - val_loss: 2.4130 - val_mean_absolute_error: 1.2205
# Epoch 43/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4706 - mean_absolute_error: 1.1643 - val_loss: 1.4348 - val_mean_absolute_error: 0.8835
# Epoch 44/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3543 - mean_absolute_error: 1.1026 - val_loss: 2.0743 - val_mean_absolute_error: 1.1432
# Epoch 45/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8203 - mean_absolute_error: 1.2527 - val_loss: 2.3291 - val_mean_absolute_error: 1.2187
# Epoch 46/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4121 - mean_absolute_error: 1.1172 - val_loss: 1.7990 - val_mean_absolute_error: 1.0463
# Epoch 47/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3927 - mean_absolute_error: 1.0964 - val_loss: 3.4290 - val_mean_absolute_error: 1.5319
# Epoch 48/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3430 - mean_absolute_error: 1.4017 - val_loss: 1.7038 - val_mean_absolute_error: 0.9952
# Epoch 49/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7122 - mean_absolute_error: 1.1984 - val_loss: 1.5079 - val_mean_absolute_error: 0.9253
# Epoch 50/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8905 - mean_absolute_error: 1.2562 - val_loss: 2.0119 - val_mean_absolute_error: 1.0855
# Epoch 51/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9196 - mean_absolute_error: 1.2834 - val_loss: 2.2738 - val_mean_absolute_error: 1.1748
# Epoch 52/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2303 - mean_absolute_error: 1.0650 - val_loss: 1.6476 - val_mean_absolute_error: 0.9875
# Epoch 53/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8216 - mean_absolute_error: 1.2395 - val_loss: 1.5666 - val_mean_absolute_error: 0.9272
# Epoch 54/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5729 - mean_absolute_error: 1.1445 - val_loss: 2.8917 - val_mean_absolute_error: 1.3791
# Epoch 55/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5513 - mean_absolute_error: 1.1988 - val_loss: 2.5554 - val_mean_absolute_error: 1.2734
# Epoch 56/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4002 - mean_absolute_error: 1.1175 - val_loss: 1.5635 - val_mean_absolute_error: 0.9202
# Epoch 57/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2269 - mean_absolute_error: 1.0823 - val_loss: 1.5935 - val_mean_absolute_error: 0.9317
# Epoch 58/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5131 - mean_absolute_error: 1.1327 - val_loss: 2.2113 - val_mean_absolute_error: 1.1506
# Epoch 59/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8933 - mean_absolute_error: 1.2551 - val_loss: 1.5957 - val_mean_absolute_error: 0.9349
# Epoch 60/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8633 - mean_absolute_error: 1.2491 - val_loss: 5.4650 - val_mean_absolute_error: 2.0490
# Epoch 61/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6221 - mean_absolute_error: 1.4257 - val_loss: 1.7948 - val_mean_absolute_error: 0.9990
# Epoch 62/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7665 - mean_absolute_error: 1.1782 - val_loss: 2.0319 - val_mean_absolute_error: 1.0890
# Epoch 63/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5294 - mean_absolute_error: 1.1561 - val_loss: 2.1736 - val_mean_absolute_error: 1.1497
# Epoch 64/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4296 - mean_absolute_error: 1.3804 - val_loss: 1.6747 - val_mean_absolute_error: 0.9936
# Epoch 65/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9065 - mean_absolute_error: 1.2499 - val_loss: 1.5760 - val_mean_absolute_error: 0.9277
# Epoch 66/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2279 - mean_absolute_error: 1.0774 - val_loss: 2.8769 - val_mean_absolute_error: 1.4028
# Epoch 67/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9139 - mean_absolute_error: 1.2302 - val_loss: 3.6234 - val_mean_absolute_error: 1.6288
# Epoch 68/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7765 - mean_absolute_error: 1.4840 - val_loss: 1.4359 - val_mean_absolute_error: 0.8847
# Epoch 69/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5057 - mean_absolute_error: 1.1369 - val_loss: 3.5496 - val_mean_absolute_error: 1.6144
# Epoch 70/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2542 - mean_absolute_error: 1.3407 - val_loss: 1.4805 - val_mean_absolute_error: 0.8924
# Epoch 71/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9678 - mean_absolute_error: 1.2802 - val_loss: 1.8431 - val_mean_absolute_error: 1.0731
# Epoch 72/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3551 - mean_absolute_error: 1.3632 - val_loss: 1.4603 - val_mean_absolute_error: 0.8999
# Epoch 73/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9229 - mean_absolute_error: 1.1900 - val_loss: 1.5591 - val_mean_absolute_error: 0.9202
# Epoch 74/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1673 - mean_absolute_error: 1.3294 - val_loss: 3.0366 - val_mean_absolute_error: 1.4152
# Epoch 75/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5929 - mean_absolute_error: 1.1738 - val_loss: 2.3672 - val_mean_absolute_error: 1.2118
# Epoch 76/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5908 - mean_absolute_error: 1.1689 - val_loss: 2.4819 - val_mean_absolute_error: 1.2497
# Epoch 77/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2167 - mean_absolute_error: 1.3408 - val_loss: 1.6037 - val_mean_absolute_error: 0.9411
# Epoch 78/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2240 - mean_absolute_error: 1.3322 - val_loss: 1.4799 - val_mean_absolute_error: 0.8942
# Epoch 79/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6262 - mean_absolute_error: 1.1588 - val_loss: 1.6063 - val_mean_absolute_error: 0.9414
# Epoch 80/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7000 - mean_absolute_error: 1.1957 - val_loss: 1.4791 - val_mean_absolute_error: 0.9056
# Epoch 81/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5943 - mean_absolute_error: 1.1680 - val_loss: 1.4812 - val_mean_absolute_error: 0.8996
# Epoch 82/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5328 - mean_absolute_error: 1.1460 - val_loss: 1.5096 - val_mean_absolute_error: 0.9044
# Epoch 83/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9469 - mean_absolute_error: 1.2537 - val_loss: 1.4873 - val_mean_absolute_error: 0.9119
# Epoch 84/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4157 - mean_absolute_error: 1.1008 - val_loss: 1.6316 - val_mean_absolute_error: 0.9786
# Epoch 85/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3018 - mean_absolute_error: 1.3273 - val_loss: 2.6931 - val_mean_absolute_error: 1.3491
# Epoch 86/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6902 - mean_absolute_error: 1.1434 - val_loss: 1.6186 - val_mean_absolute_error: 0.9745
# Epoch 87/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8827 - mean_absolute_error: 1.2250 - val_loss: 1.7640 - val_mean_absolute_error: 0.9947
# Epoch 88/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8617 - mean_absolute_error: 1.4164 - val_loss: 2.4182 - val_mean_absolute_error: 1.2294
# Epoch 89/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0527 - mean_absolute_error: 1.2792 - val_loss: 1.4745 - val_mean_absolute_error: 0.9037
# Epoch 90/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6012 - mean_absolute_error: 1.1654 - val_loss: 1.5884 - val_mean_absolute_error: 0.9359
# Epoch 91/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6745 - mean_absolute_error: 1.1556 - val_loss: 3.6087 - val_mean_absolute_error: 1.5806
# Epoch 92/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0236 - mean_absolute_error: 1.2853 - val_loss: 1.9776 - val_mean_absolute_error: 1.0713
# Epoch 93/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3478 - mean_absolute_error: 1.1297 - val_loss: 2.8747 - val_mean_absolute_error: 1.3641
# Epoch 94/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6803 - mean_absolute_error: 1.2005 - val_loss: 2.2354 - val_mean_absolute_error: 1.1963
# Epoch 95/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0132 - mean_absolute_error: 1.3125 - val_loss: 3.0644 - val_mean_absolute_error: 1.4269
# Epoch 96/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9502 - mean_absolute_error: 1.2767 - val_loss: 3.7261 - val_mean_absolute_error: 1.6537
# Epoch 97/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4568 - mean_absolute_error: 1.3509 - val_loss: 2.7374 - val_mean_absolute_error: 1.3308
# Epoch 98/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7428 - mean_absolute_error: 1.2348 - val_loss: 1.6893 - val_mean_absolute_error: 0.9687
# Epoch 99/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2300 - mean_absolute_error: 1.0897 - val_loss: 1.8237 - val_mean_absolute_error: 1.0144
# Epoch 100/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3103 - mean_absolute_error: 1.0813 - val_loss: 1.8839 - val_mean_absolute_error: 1.0736

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(["Training Predictions", "Training Observations"])
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score,
    mean_absolute_percentage_error,
    explained_variance_score,
)
import numpy as np

mae = mean_absolute_error(y_train, train_predictions)
mse = mean_squared_error(y_train, train_predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_train, train_predictions)
mape = mean_absolute_percentage_error(y_train, train_predictions)
explained_var = explained_variance_score(y_train, train_predictions)

print(f"MAE: {mae:.4f}")
print(f"MSE: {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"R² Score: {r2:.4f}")
print(f"MAPE: {mape:.4f}")
print(f"Explained Variance: {explained_var:.4f}")
# Out:
# MAE: 1.1215
# MSE: 2.4570
# RMSE: 1.5675
# R² Score: 0.9982
# MAPE: 0.0108
# Explained Variance: 0.9984

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(["Validation Predictions", "Validation Observations"])
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
mae = mean_absolute_error(y_val, val_predictions)
mse = mean_squared_error(y_val, val_predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_val, val_predictions)
mape = mean_absolute_percentage_error(y_val, val_predictions)
explained_var = explained_variance_score(y_val, val_predictions)

print(f"MAE: {mae:.4f}")
print(f"MSE: {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"R² Score: {r2:.4f}")
print(f"MAPE: {mape:.4f}")
print(f"Explained Variance: {explained_var:.4f}")
# Out:
# MAE: 1.0736
# MSE: 1.8839
# RMSE: 1.3726
# R² Score: 0.9364
# MAPE: 0.0090
# Explained Variance: 0.9507

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(["Testing Predictions", "Testing Observations"])
plt.xlabel("Year-Month")  # x-axis label
plt.ylabel("Open Price")  # y-axis label
plt.title("Testing Predictions vs Observations")
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# your data
# dates_test, y_test, test_predictions
test_predictions = model.predict(X_test).flatten()

fig, ax = plt.subplots(figsize=(12, 6))

# force a white background
fig.patch.set_facecolor("white")
ax.set_facecolor("white")

# plot the actuals
ax.plot(
    dates_test, y_test, label="Testing Observations", color="tab:blue", linewidth=1.5
)

# plot the preds
ax.plot(
    dates_test,
    test_predictions,
    label="Testing Predictions",
    color="tab:orange",
    linestyle="--",
    linewidth=1.5,
)

# labels & title
ax.set_xlabel("Year-Month")
ax.set_ylabel("Open Price")
ax.set_title("Testing Predictions vs Observations", pad=12)

# legend
ax.legend(loc="upper left")

# dashed grid
ax.grid(True, which="major", linestyle="--", linewidth=0.5, alpha=0.7)

# nice date formatting
# choose a locator (e.g. every 3 months) or leave default
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))

# format as YYYY-MM
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))

# rotate if needed
fig.autofmt_xdate()

plt.tight_layout()
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step

# %%
# y_test and test_predictions should be 1D arrays or Series
mae = mean_absolute_error(y_test, test_predictions)

# MAE % relative to the mean of actuals
mae_pct = mae / np.mean(y_test) * 100

# Directional Accuracy: how often the model gets the up/down move right
actual_dir = np.sign(np.diff(y_test))
pred_dir = np.sign(np.diff(test_predictions))
directional_accuracy = np.mean(actual_dir == pred_dir)

# R² score
r2 = r2_score(y_test, test_predictions)

# print them out
print(f"MAE: {mae:.4f}")
print(f"MAE %: {mae_pct:.2f}%")
print(f"Directional Accuracy: {directional_accuracy:.4f}")
print(f"R² Score: {r2:.4f}")
# Out:
# MAE: 0.8160
# MAE %: 0.67%
# Directional Accuracy: 0.4880
# R² Score: 0.8965

# %%
mae = mean_absolute_error(y_test, test_predictions)
mse = mean_squared_error(y_test, test_predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, test_predictions)
mape = mean_absolute_percentage_error(y_test, test_predictions)
explained_var = explained_variance_score(y_test, test_predictions)

print(f"MAE: {mae:.4f}")
print(f"MSE: {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"R² Score: {r2:.4f}")
print(f"MAPE: {mape:.4f}")
print(f"Explained Variance: {explained_var:.4f}")
# Out:
# MAE: 0.8160
# MSE: 1.0312
# RMSE: 1.0155
# R² Score: 0.8965
# MAPE: 0.0067
# Explained Variance: 0.9419

# %%
directional_accuracy
# Out:
# 0.4879725085910653
