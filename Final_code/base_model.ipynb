# %%
# https://www.youtube.com/watch?v=CbTU92pbDKw

# %%
import yfinance as yf
import pandas as pd

ticker = "GLD"
gold_data = yf.download(
    ticker,
    start="2000-01-01",
    end=None,
    progress=False,
    auto_adjust=False,
    actions=True,
)
gold_data
# Out:
# Price        Adj Close Capital Gains       Close Dividends        High  \
# Ticker             GLD           GLD         GLD       GLD         GLD
# Date
# 2004-11-18   44.380001           0.0   44.380001       0.0   44.490002
# 2004-11-19   44.779999           0.0   44.779999       0.0   44.919998
# 2004-11-22   44.950001           0.0   44.950001       0.0   44.970001
# 2004-11-23   44.750000           0.0   44.750000       0.0   44.919998
# 2004-11-24   45.049999           0.0   45.049999       0.0   45.049999
# ...                ...           ...         ...       ...         ...
# 2025-04-23  303.649994           0.0  303.649994       0.0  304.739990
# 2025-04-24  308.070007           0.0  308.070007       0.0  308.500000
# 2025-04-25  304.730011           0.0  304.730011       0.0  305.369995
# 2025-04-28  309.070007           0.0  309.070007       0.0  309.109985
# 2025-04-29  304.630005           0.0  304.630005       0.0  306.160004
#
# Price              Low        Open Stock Splits    Volume
# Ticker             GLD         GLD          GLD       GLD
# Date
# 2004-11-18   44.070000   44.430000          0.0   5992000
# 2004-11-19   44.470001   44.490002          0.0  11655300
# 2004-11-22   44.740002   44.750000          0.0  11996000
# 2004-11-23   44.720001   44.880001          0.0   3169200
# 2004-11-24   44.790001   44.930000          0.0   6105100
# ...                ...         ...          ...       ...
# 2025-04-23  300.589996  304.179993          0.0  25421500
# 2025-04-24  304.709991  306.980011          0.0  10845000
# 2025-04-25  301.010010  301.779999          0.0  10691600
# 2025-04-28  302.970001  304.149994          0.0   9329500
# 2025-04-29  304.559998  305.809998          0.0   1026140
#
# [5143 rows x 9 columns]

# %%
finbert_score = pd.read_csv("../Final_sentiment_score.csv")
finbert_score = finbert_score[["Date", "Positive", "Neutral", "Negative"]]
finbert_score
# Out:
#             Date  Positive   Neutral  Negative
# 0     2000-02-15  0.398276  0.585515  0.016209
# 1     2000-02-17  0.077722  0.095735  0.826543
# 2     2000-03-24  0.180700  0.287722  0.531578
# 3     2000-04-27  0.393267  0.346374  0.260358
# 4     2000-05-04  0.337279  0.255016  0.407705
# ...          ...       ...       ...       ...
# 3667  2019-01-25  0.786646  0.120372  0.092982
# 3668  2019-01-28  0.749922  0.169181  0.080897
# 3669  2019-01-30  0.790114  0.135270  0.074616
# 3670  2019-01-31  0.128171  0.481111  0.390717
# 3671  2019-02-01  0.080484  0.883677  0.035839
#
# [3672 rows x 4 columns]

# %%
finbert_score["Date"] = pd.to_datetime(finbert_score["Date"])

# %%
gold_data.reset_index(inplace=True)
gold_data.columns = [col[0] for col in gold_data.columns]

gold_data["Date"] = pd.to_datetime(gold_data["Date"])

# %%
merged_df = pd.merge(
    finbert_score, gold_data, left_on="Date", right_on="Date", how="inner"
)

# %%
df = merged_df[["Date", "Open"]]

df
# Out:
#            Date        Open
# 0    2004-11-18   44.430000
# 1    2004-11-19   44.490002
# 2    2004-11-22   44.750000
# 3    2004-11-23   44.880001
# 4    2004-11-24   44.930000
# ...         ...         ...
# 2914 2019-01-25  122.019997
# 2915 2019-01-28  122.750000
# 2916 2019-01-30  123.910004
# 2917 2019-01-31  125.180000
# 2918 2019-02-01  124.889999
#
# [2919 rows x 2 columns]

# %%
# make date the index
df.index = df.pop("Date")
df
# Out:
#                   Open
# Date
# 2004-11-18   44.430000
# 2004-11-19   44.490002
# 2004-11-22   44.750000
# 2004-11-23   44.880001
# 2004-11-24   44.930000
# ...                ...
# 2019-01-25  122.019997
# 2019-01-28  122.750000
# 2019-01-30  123.910004
# 2019-01-31  125.180000
# 2019-02-01  124.889999
#
# [2919 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df["Open"])

# %%
import numpy as np
import pandas as pd


def df_to_windowed_df(dataframe, n=3):
    dates = []
    X, Y = [], []

    for i in range(n, len(dataframe)):
        window = dataframe.iloc[i - n : i + 1]  # n previous + 1 target row

        if len(window) != n + 1:
            continue  # skip if not enough data

        values = window[["Open"]].to_numpy()
        x, y = values[:-1], values[-1][0]

        dates.append(dataframe.index[i])  # the date corresponding to the target
        X.append(x.flatten())  # flatten to 1D array of n values
        Y.append(y)

    ret_df = pd.DataFrame({"Target Date": dates})

    X = np.array(X)  # shape (num_samples, n)
    for i in range(n):
        ret_df[f"Target-{n - i}"] = X[:, i]  # each column is Open value at t-n+i

    ret_df["Target"] = Y

    return ret_df

# %%
windowed_df = df_to_windowed_df(df, n=3)
windowed_df
# Out:
#      Target Date    Target-3    Target-2    Target-1      Target
# 0     2004-11-23   44.430000   44.490002   44.750000   44.880001
# 1     2004-11-24   44.490002   44.750000   44.880001   44.930000
# 2     2004-11-29   44.750000   44.880001   44.930000   45.099998
# 3     2004-11-30   44.880001   44.930000   45.099998   45.369999
# 4     2004-12-01   44.930000   45.099998   45.369999   45.279999
# ...          ...         ...         ...         ...         ...
# 2911  2019-01-25  122.279999  120.959999  121.160004  122.019997
# 2912  2019-01-28  120.959999  121.160004  122.019997  122.750000
# 2913  2019-01-30  121.160004  122.019997  122.750000  123.910004
# 2914  2019-01-31  122.019997  122.750000  123.910004  125.180000
# 2915  2019-02-01  122.750000  123.910004  125.180000  124.889999
#
# [2916 rows x 5 columns]

# %%
df
# Out:
#                   Open
# Date
# 2004-11-18   44.430000
# 2004-11-19   44.490002
# 2004-11-22   44.750000
# 2004-11-23   44.880001
# 2004-11-24   44.930000
# ...                ...
# 2019-01-25  122.019997
# 2019-01-28  122.750000
# 2019-01-30  123.910004
# 2019-01-31  125.180000
# 2019-02-01  124.889999
#
# [2919 rows x 1 columns]

# %%
# date, Input -> X, output -> Y
def windowed_df_to_date_X_y(windowed_dataframe):
    df_as_np = windowed_dataframe.to_numpy()

    # getting the dates
    dates = df_as_np[:, 0]

    # we want the target window columns only and not the last one
    middle_matrix = df_as_np[:, 1:-1]
    # we need to reshape this
    X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

    # ouput vector
    Y = df_as_np[:, -1]

    return dates, X.astype(np.float32), Y.astype(np.float32)


dates, X, y = windowed_df_to_date_X_y(windowed_df)

# check all the shapes
dates.shape, X.shape, y.shape
# Out:
# ((2916,), (2916, 3, 1), (2916,))

# %%
# training part
q_75 = int(len(dates) * 0.75)

# validation part
q_85 = int(len(dates) * 0.85)

# testing part
q_95 = int(len(dates) * 0.95)

dates_train, X_train, y_train = dates[:q_75], X[:q_75], y[:q_75]
dates_val, X_val, y_val = dates[q_75:q_85], X[q_75:q_85], y[q_75:q_85]
dates_test, X_test, y_test = dates[q_85:q_95], X[q_85:q_95], y[q_85:q_95]
dates_hold, X_hold, y_hold = dates[q_95:], X[q_95:], y[q_95:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(["Train", "Validation", "Test"])
plt.xlabel("Date")
plt.ylabel("Target Value")
plt.title("Train / Validation / Test Split")
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential(
    [
        layers.Input((3, 1)),  # window size = 3, feature = 1
        layers.LSTM(64),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(1),
    ]
)  # since the output we want is just 1

model.compile(
    loss="mse", optimizer=Adam(learning_rate=0.001), metrics=["mean_absolute_error"]
)

model.fit(
    X_train, y_train, validation_data=(X_val, y_val), epochs=100
)  # 100 runs through the dataset
# Out:
# Epoch 1/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13004.9902 - mean_absolute_error: 107.7310 - val_loss: 10653.3867 - val_mean_absolute_error: 103.0655
# Epoch 2/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6744.7739 - mean_absolute_error: 71.0377 - val_loss: 106.6935 - val_mean_absolute_error: 9.0456
# Epoch 3/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 939.5697 - mean_absolute_error: 23.7147 - val_loss: 2.2245 - val_mean_absolute_error: 1.1666
# Epoch 4/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 20.4133 - mean_absolute_error: 2.4536 - val_loss: 2.0226 - val_mean_absolute_error: 1.0810
# Epoch 5/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.9178 - mean_absolute_error: 1.6078 - val_loss: 1.6312 - val_mean_absolute_error: 0.9826
# Epoch 6/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4363 - mean_absolute_error: 1.2686 - val_loss: 1.8190 - val_mean_absolute_error: 1.0109
# Epoch 7/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0637 - mean_absolute_error: 1.2149 - val_loss: 1.6329 - val_mean_absolute_error: 0.9762
# Epoch 8/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3237 - mean_absolute_error: 1.2796 - val_loss: 2.3254 - val_mean_absolute_error: 1.1874
# Epoch 9/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4011 - mean_absolute_error: 1.3612 - val_loss: 1.8221 - val_mean_absolute_error: 1.0118
# Epoch 10/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8244 - mean_absolute_error: 1.2039 - val_loss: 2.0320 - val_mean_absolute_error: 1.0863
# Epoch 11/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8987 - mean_absolute_error: 1.2324 - val_loss: 2.1114 - val_mean_absolute_error: 1.1543
# Epoch 12/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3789 - mean_absolute_error: 1.3262 - val_loss: 1.6024 - val_mean_absolute_error: 0.9346
# Epoch 13/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5478 - mean_absolute_error: 1.1466 - val_loss: 2.5233 - val_mean_absolute_error: 1.3019
# Epoch 14/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3527 - mean_absolute_error: 1.3734 - val_loss: 2.8320 - val_mean_absolute_error: 1.3436
# Epoch 15/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1045 - mean_absolute_error: 1.2767 - val_loss: 1.4740 - val_mean_absolute_error: 0.9055
# Epoch 16/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8684 - mean_absolute_error: 1.2185 - val_loss: 1.5272 - val_mean_absolute_error: 0.9336
# Epoch 17/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6539 - mean_absolute_error: 1.1563 - val_loss: 2.7574 - val_mean_absolute_error: 1.3267
# Epoch 18/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1407 - mean_absolute_error: 1.2946 - val_loss: 2.4008 - val_mean_absolute_error: 1.2430
# Epoch 19/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0884 - mean_absolute_error: 1.2830 - val_loss: 1.8248 - val_mean_absolute_error: 1.0139
# Epoch 20/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9395 - mean_absolute_error: 1.2559 - val_loss: 2.2189 - val_mean_absolute_error: 1.1978
# Epoch 21/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9130 - mean_absolute_error: 1.2307 - val_loss: 2.0376 - val_mean_absolute_error: 1.0896
# Epoch 22/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6328 - mean_absolute_error: 1.1782 - val_loss: 1.9714 - val_mean_absolute_error: 1.0993
# Epoch 23/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5947 - mean_absolute_error: 1.3748 - val_loss: 4.1115 - val_mean_absolute_error: 1.7656
# Epoch 24/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1247 - mean_absolute_error: 1.2823 - val_loss: 1.7633 - val_mean_absolute_error: 1.0275
# Epoch 25/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4956 - mean_absolute_error: 1.1550 - val_loss: 4.5052 - val_mean_absolute_error: 1.8135
# Epoch 26/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1784 - mean_absolute_error: 1.3230 - val_loss: 3.5789 - val_mean_absolute_error: 1.5630
# Epoch 27/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7019 - mean_absolute_error: 1.4476 - val_loss: 1.4962 - val_mean_absolute_error: 0.9155
# Epoch 28/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5514 - mean_absolute_error: 1.1528 - val_loss: 2.1346 - val_mean_absolute_error: 1.1728
# Epoch 29/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5749 - mean_absolute_error: 1.1907 - val_loss: 1.5357 - val_mean_absolute_error: 0.9383
# Epoch 30/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4747 - mean_absolute_error: 1.1337 - val_loss: 1.8979 - val_mean_absolute_error: 1.0770
# Epoch 31/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2599 - mean_absolute_error: 1.3070 - val_loss: 1.5387 - val_mean_absolute_error: 0.9372
# Epoch 32/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3459 - mean_absolute_error: 1.0969 - val_loss: 2.2961 - val_mean_absolute_error: 1.2250
# Epoch 33/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9840 - mean_absolute_error: 1.2700 - val_loss: 2.4125 - val_mean_absolute_error: 1.2459
# Epoch 34/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7987 - mean_absolute_error: 1.2149 - val_loss: 1.8929 - val_mean_absolute_error: 1.0392
# Epoch 35/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7139 - mean_absolute_error: 1.2016 - val_loss: 1.7940 - val_mean_absolute_error: 1.0029
# Epoch 36/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8202 - mean_absolute_error: 1.1948 - val_loss: 1.7073 - val_mean_absolute_error: 1.0091
# Epoch 37/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7466 - mean_absolute_error: 1.2294 - val_loss: 2.6366 - val_mean_absolute_error: 1.3152
# Epoch 38/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9000 - mean_absolute_error: 1.2666 - val_loss: 1.6089 - val_mean_absolute_error: 0.9555
# Epoch 39/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8912 - mean_absolute_error: 1.1913 - val_loss: 1.8630 - val_mean_absolute_error: 1.0284
# Epoch 40/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3040 - mean_absolute_error: 1.3316 - val_loss: 1.6432 - val_mean_absolute_error: 0.9500
# Epoch 41/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6636 - mean_absolute_error: 1.1966 - val_loss: 5.1777 - val_mean_absolute_error: 1.9718
# Epoch 42/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8039 - mean_absolute_error: 1.2109 - val_loss: 2.6134 - val_mean_absolute_error: 1.3211
# Epoch 43/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6924 - mean_absolute_error: 1.1882 - val_loss: 1.5561 - val_mean_absolute_error: 0.9457
# Epoch 44/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8739 - mean_absolute_error: 1.2189 - val_loss: 1.7973 - val_mean_absolute_error: 1.0056
# Epoch 45/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7670 - mean_absolute_error: 1.2002 - val_loss: 1.7165 - val_mean_absolute_error: 0.9778
# Epoch 46/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5610 - mean_absolute_error: 1.1244 - val_loss: 1.6939 - val_mean_absolute_error: 1.0022
# Epoch 47/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1890 - mean_absolute_error: 1.3265 - val_loss: 2.8260 - val_mean_absolute_error: 1.3918
# Epoch 48/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9484 - mean_absolute_error: 1.2509 - val_loss: 2.3771 - val_mean_absolute_error: 1.2358
# Epoch 49/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9311 - mean_absolute_error: 1.2591 - val_loss: 1.5129 - val_mean_absolute_error: 0.9144
# Epoch 50/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6800 - mean_absolute_error: 1.1577 - val_loss: 1.8114 - val_mean_absolute_error: 1.0090
# Epoch 51/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6091 - mean_absolute_error: 1.1703 - val_loss: 3.1529 - val_mean_absolute_error: 1.4471
# Epoch 52/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5239 - mean_absolute_error: 1.4047 - val_loss: 1.5868 - val_mean_absolute_error: 0.9617
# Epoch 53/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9100 - mean_absolute_error: 1.2223 - val_loss: 1.6922 - val_mean_absolute_error: 0.9654
# Epoch 54/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4958 - mean_absolute_error: 1.1482 - val_loss: 1.7176 - val_mean_absolute_error: 0.9769
# Epoch 55/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5056 - mean_absolute_error: 1.1235 - val_loss: 1.6314 - val_mean_absolute_error: 0.9665
# Epoch 56/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8863 - mean_absolute_error: 1.2401 - val_loss: 1.9848 - val_mean_absolute_error: 1.1073
# Epoch 57/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5715 - mean_absolute_error: 1.1509 - val_loss: 1.4859 - val_mean_absolute_error: 0.9078
# Epoch 58/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8798 - mean_absolute_error: 1.2289 - val_loss: 2.1915 - val_mean_absolute_error: 1.1777
# Epoch 59/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9841 - mean_absolute_error: 1.2417 - val_loss: 2.4940 - val_mean_absolute_error: 1.2696
# Epoch 60/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6573 - mean_absolute_error: 1.1840 - val_loss: 1.7045 - val_mean_absolute_error: 0.9772
# Epoch 61/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0753 - mean_absolute_error: 1.2998 - val_loss: 2.8025 - val_mean_absolute_error: 1.3328
# Epoch 62/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9432 - mean_absolute_error: 1.2714 - val_loss: 3.2765 - val_mean_absolute_error: 1.4778
# Epoch 63/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5550 - mean_absolute_error: 1.1419 - val_loss: 1.7248 - val_mean_absolute_error: 0.9828
# Epoch 64/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7482 - mean_absolute_error: 1.2173 - val_loss: 1.8624 - val_mean_absolute_error: 1.0274
# Epoch 65/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2606 - mean_absolute_error: 1.0981 - val_loss: 1.5416 - val_mean_absolute_error: 0.9415
# Epoch 66/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5671 - mean_absolute_error: 1.1484 - val_loss: 1.6031 - val_mean_absolute_error: 0.9416
# Epoch 67/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3078 - mean_absolute_error: 1.3699 - val_loss: 1.4942 - val_mean_absolute_error: 0.9093
# Epoch 68/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4282 - mean_absolute_error: 1.1125 - val_loss: 2.6141 - val_mean_absolute_error: 1.2731
# Epoch 69/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8693 - mean_absolute_error: 1.2427 - val_loss: 3.4223 - val_mean_absolute_error: 1.5221
# Epoch 70/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7202 - mean_absolute_error: 1.1864 - val_loss: 1.4892 - val_mean_absolute_error: 0.9089
# Epoch 71/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7452 - mean_absolute_error: 1.2166 - val_loss: 1.7123 - val_mean_absolute_error: 1.0029
# Epoch 72/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7057 - mean_absolute_error: 1.2082 - val_loss: 1.7006 - val_mean_absolute_error: 1.0107
# Epoch 73/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6826 - mean_absolute_error: 1.1955 - val_loss: 2.0922 - val_mean_absolute_error: 1.1528
# Epoch 74/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1189 - mean_absolute_error: 1.2856 - val_loss: 2.3686 - val_mean_absolute_error: 1.1967
# Epoch 75/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7036 - mean_absolute_error: 1.1776 - val_loss: 1.6814 - val_mean_absolute_error: 1.0078
# Epoch 76/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8999 - mean_absolute_error: 1.2791 - val_loss: 1.5204 - val_mean_absolute_error: 0.9326
# Epoch 77/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5002 - mean_absolute_error: 1.1452 - val_loss: 1.5970 - val_mean_absolute_error: 0.9363
# Epoch 78/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2039 - mean_absolute_error: 1.3222 - val_loss: 2.3963 - val_mean_absolute_error: 1.2046
# Epoch 79/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8051 - mean_absolute_error: 1.2297 - val_loss: 1.5418 - val_mean_absolute_error: 0.9216
# Epoch 80/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6483 - mean_absolute_error: 1.1648 - val_loss: 1.7958 - val_mean_absolute_error: 1.0405
# Epoch 81/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5153 - mean_absolute_error: 1.1512 - val_loss: 1.7683 - val_mean_absolute_error: 1.0338
# Epoch 82/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5901 - mean_absolute_error: 1.1879 - val_loss: 2.1809 - val_mean_absolute_error: 1.1672
# Epoch 83/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6972 - mean_absolute_error: 1.2085 - val_loss: 1.8850 - val_mean_absolute_error: 1.0448
# Epoch 84/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3500 - mean_absolute_error: 1.3443 - val_loss: 1.6806 - val_mean_absolute_error: 0.9694
# Epoch 85/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3097 - mean_absolute_error: 1.1018 - val_loss: 3.2351 - val_mean_absolute_error: 1.5193
# Epoch 86/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2441 - mean_absolute_error: 1.3571 - val_loss: 3.3818 - val_mean_absolute_error: 1.5005
# Epoch 87/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9721 - mean_absolute_error: 1.2836 - val_loss: 1.6066 - val_mean_absolute_error: 0.9409
# Epoch 88/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6652 - mean_absolute_error: 1.1776 - val_loss: 1.6118 - val_mean_absolute_error: 0.9416
# Epoch 89/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8438 - mean_absolute_error: 1.1691 - val_loss: 2.1982 - val_mean_absolute_error: 1.1500
# Epoch 90/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9597 - mean_absolute_error: 1.2628 - val_loss: 2.9121 - val_mean_absolute_error: 1.3590
# Epoch 91/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 3.0207 - mean_absolute_error: 1.2588 - val_loss: 2.2148 - val_mean_absolute_error: 1.1825
# Epoch 92/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2614 - mean_absolute_error: 1.3310 - val_loss: 2.0079 - val_mean_absolute_error: 1.1257
# Epoch 93/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6168 - mean_absolute_error: 1.1984 - val_loss: 2.0204 - val_mean_absolute_error: 1.1320
# Epoch 94/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9461 - mean_absolute_error: 1.2505 - val_loss: 2.0074 - val_mean_absolute_error: 1.1161
# Epoch 95/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9868 - mean_absolute_error: 1.2630 - val_loss: 3.1161 - val_mean_absolute_error: 1.4243
# Epoch 96/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0381 - mean_absolute_error: 1.3109 - val_loss: 1.6321 - val_mean_absolute_error: 0.9716
# Epoch 97/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9058 - mean_absolute_error: 1.2052 - val_loss: 2.1653 - val_mean_absolute_error: 1.1339
# Epoch 98/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9783 - mean_absolute_error: 1.2582 - val_loss: 1.7520 - val_mean_absolute_error: 0.9958
# Epoch 99/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5884 - mean_absolute_error: 1.1373 - val_loss: 2.3195 - val_mean_absolute_error: 1.2308
# Epoch 100/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6833 - mean_absolute_error: 1.2079 - val_loss: 2.8102 - val_mean_absolute_error: 1.3720

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(["Training Predictions", "Training Observations"])
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score,
    mean_absolute_percentage_error,
    explained_variance_score,
)
import numpy as np

mae = mean_absolute_error(y_train, train_predictions)
mse = mean_squared_error(y_train, train_predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_train, train_predictions)
mape = mean_absolute_percentage_error(y_train, train_predictions)
explained_var = explained_variance_score(y_train, train_predictions)

print(f"MAE: {mae:.4f}")
print(f"MSE: {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"R² Score: {r2:.4f}")
print(f"MAPE: {mape:.4f}")
print(f"Explained Variance: {explained_var:.4f}")
# Out:
# MAE: 1.3503
# MSE: 3.3768
# RMSE: 1.8376
# R² Score: 0.9976
# MAPE: 0.0123
# Explained Variance: 0.9981

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(["Validation Predictions", "Validation Observations"])
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
mae = mean_absolute_error(y_val, val_predictions)
mse = mean_squared_error(y_val, val_predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_val, val_predictions)
mape = mean_absolute_percentage_error(y_val, val_predictions)
explained_var = explained_variance_score(y_val, val_predictions)

print(f"MAE: {mae:.4f}")
print(f"MSE: {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"R² Score: {r2:.4f}")
print(f"MAPE: {mape:.4f}")
print(f"Explained Variance: {explained_var:.4f}")
# Out:
# MAE: 1.3720
# MSE: 2.8102
# RMSE: 1.6764
# R² Score: 0.9051
# MAPE: 0.0115
# Explained Variance: 0.9463

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# your data
# dates_test, y_test, test_predictions
test_predictions = model.predict(X_test).flatten()

fig, ax = plt.subplots(figsize=(12, 6))

# force a white background
fig.patch.set_facecolor("white")
ax.set_facecolor("white")

# plot the actuals
ax.plot(
    dates_test, y_test, label="Testing Observations", color="tab:blue", linewidth=1.5
)

# plot the preds
ax.plot(
    dates_test,
    test_predictions,
    label="Testing Predictions",
    color="tab:orange",
    linestyle="--",
    linewidth=1.5,
)

# labels & title
ax.set_xlabel("Year-Month")
ax.set_ylabel("Open Price")
ax.set_title("Testing Predictions vs Observations", pad=12)

# legend
ax.legend(loc="upper left")

# dashed grid
ax.grid(True, which="major", linestyle="--", linewidth=0.5, alpha=0.7)

# nice date formatting
# choose a locator (e.g. every 3 months) or leave default
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))

# format as YYYY-MM
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))

# rotate if needed
fig.autofmt_xdate()

plt.tight_layout()
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
# y_test and test_predictions should be 1D arrays or Series
mae = mean_absolute_error(y_test, test_predictions)

# MAE % relative to the mean of actuals
mae_pct = mae / np.mean(y_test) * 100

# Directional Accuracy: how often the model gets the up/down move right
actual_dir = np.sign(np.diff(y_test))
pred_dir = np.sign(np.diff(test_predictions))
directional_accuracy = np.mean(actual_dir == pred_dir)

# R² score
r2 = r2_score(y_test, test_predictions)

# print them out
print(f"MAE: {mae:.4f}")
print(f"MAE %: {mae_pct:.2f}%")
print(f"Directional Accuracy: {directional_accuracy:.4f}")
print(f"R² Score: {r2:.4f}")
# Out:
# MAE: 1.2525
# MAE %: 1.02%
# Directional Accuracy: 0.4811
# R² Score: 0.7905

# %%
# take the sign of the step-to-step changes
actual_dir = np.sign(np.diff(y_test))
pred_dir = np.sign(np.diff(test_predictions))

directional_accuracy = np.mean(actual_dir == pred_dir)
print(f"Directional Accuracy: {directional_accuracy:.4f}")
# Out:
# Directional Accuracy: 0.4811
