# %%
import yfinance as yf
import pandas as pd

ticker = "GLD"
gold_data = yf.download(
    ticker,
    start="2000-01-01",
    end=None,
    progress=False,
    auto_adjust=False,
    actions=True,
)
gold_data
# Out:
# Price        Adj Close Capital Gains       Close Dividends        High  \
# Ticker             GLD           GLD         GLD       GLD         GLD
# Date
# 2004-11-18   44.380001           0.0   44.380001       0.0   44.490002
# 2004-11-19   44.779999           0.0   44.779999       0.0   44.919998
# 2004-11-22   44.950001           0.0   44.950001       0.0   44.970001
# 2004-11-23   44.750000           0.0   44.750000       0.0   44.919998
# 2004-11-24   45.049999           0.0   45.049999       0.0   45.049999
# ...                ...           ...         ...       ...         ...
# 2025-04-23  303.649994           0.0  303.649994       0.0  304.739990
# 2025-04-24  308.070007           0.0  308.070007       0.0  308.500000
# 2025-04-25  304.730011           0.0  304.730011       0.0  305.369995
# 2025-04-28  309.070007           0.0  309.070007       0.0  309.109985
# 2025-04-29  304.679993           0.0  304.679993       0.0  306.160004
#
# Price              Low        Open Stock Splits    Volume
# Ticker             GLD         GLD          GLD       GLD
# Date
# 2004-11-18   44.070000   44.430000          0.0   5992000
# 2004-11-19   44.470001   44.490002          0.0  11655300
# 2004-11-22   44.740002   44.750000          0.0  11996000
# 2004-11-23   44.720001   44.880001          0.0   3169200
# 2004-11-24   44.790001   44.930000          0.0   6105100
# ...                ...         ...          ...       ...
# 2025-04-23  300.589996  304.179993          0.0  25421500
# 2025-04-24  304.709991  306.980011          0.0  10845000
# 2025-04-25  301.010010  301.779999          0.0  10691600
# 2025-04-28  302.970001  304.149994          0.0   9329500
# 2025-04-29  304.640015  305.809998          0.0   1002943
#
# [5143 rows x 9 columns]

# %%
finbert_score = pd.read_csv("../Final_sentiment_score.csv")
finbert_score = finbert_score[["Date", "Positive", "Neutral", "Negative"]]
finbert_score["sentiment"] = finbert_score["Positive"] - finbert_score["Negative"]

# %%
finbert_score
# Out:
#             Date  Positive   Neutral  Negative  sentiment
# 0     2000-02-15  0.398276  0.585515  0.016209   0.382066
# 1     2000-02-17  0.077722  0.095735  0.826543  -0.748821
# 2     2000-03-24  0.180700  0.287722  0.531578  -0.350879
# 3     2000-04-27  0.393267  0.346374  0.260358   0.132909
# 4     2000-05-04  0.337279  0.255016  0.407705  -0.070426
# ...          ...       ...       ...       ...        ...
# 3667  2019-01-25  0.786646  0.120372  0.092982   0.693664
# 3668  2019-01-28  0.749922  0.169181  0.080897   0.669025
# 3669  2019-01-30  0.790114  0.135270  0.074616   0.715498
# 3670  2019-01-31  0.128171  0.481111  0.390717  -0.262546
# 3671  2019-02-01  0.080484  0.883677  0.035839   0.044645
#
# [3672 rows x 5 columns]

# %%
finbert_score["Date"] = pd.to_datetime(finbert_score["Date"])

# %%
gold_data.reset_index(inplace=True)
gold_data.columns = [col[0] for col in gold_data.columns]

gold_data["Date"] = pd.to_datetime(gold_data["Date"])

# %%
merged_df = pd.merge(
    finbert_score, gold_data, left_on="Date", right_on="Date", how="inner"
)

# %%
df = merged_df[["Date", "Open", "sentiment"]]

df
# Out:
#            Date        Open  sentiment
# 0    2004-11-18   44.430000  -0.579322
# 1    2004-11-19   44.490002   0.726477
# 2    2004-11-22   44.750000   0.347871
# 3    2004-11-23   44.880001  -0.801077
# 4    2004-11-24   44.930000   0.892562
# ...         ...         ...        ...
# 2914 2019-01-25  122.019997   0.693664
# 2915 2019-01-28  122.750000   0.669025
# 2916 2019-01-30  123.910004   0.715498
# 2917 2019-01-31  125.180000  -0.262546
# 2918 2019-02-01  124.889999   0.044645
#
# [2919 rows x 3 columns]

# %%
# make date the index
df.index = df.pop("Date")
df
# Out:
#                   Open  sentiment
# Date
# 2004-11-18   44.430000  -0.579322
# 2004-11-19   44.490002   0.726477
# 2004-11-22   44.750000   0.347871
# 2004-11-23   44.880001  -0.801077
# 2004-11-24   44.930000   0.892562
# ...                ...        ...
# 2019-01-25  122.019997   0.693664
# 2019-01-28  122.750000   0.669025
# 2019-01-30  123.910004   0.715498
# 2019-01-31  125.180000  -0.262546
# 2019-02-01  124.889999   0.044645
#
# [2919 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df["Open"])

# %%
import numpy as np


def df_to_windowed_df(dataframe, n=3):
    dates = []
    X, Y = [], []

    for i in range(n, len(dataframe)):
        window = dataframe.iloc[i - n : i + 1]  # n previous + 1 target row

        if len(window) != n + 1:
            continue  # skip if not enough data

        values = window[["Open", "sentiment"]].to_numpy()
        x, y = values[:-1], values[-1][0]

        dates.append(dataframe.index[i])  # the date corresponding to the target
        X.append(x)
        Y.append(y)

    ret_df = pd.DataFrame({"Target Date": dates})

    X = np.array(X)
    for i in range(n):
        ret_df[f"Target-{n - i}"] = list(
            X[:, i]
        )  # each element is a pair: [Close, sentiment]

    ret_df["Target"] = Y

    return ret_df

# %%
windowed_df = df_to_windowed_df(df, n=3)
windowed_df
# Out:
#      Target Date                                   Target-3  \
# 0     2004-11-23   [44.43000030517578, -0.5793219208717346]
# 1     2004-11-24     [44.4900016784668, 0.7264769300818444]
# 2     2004-11-29                [44.75, 0.3478713557124139]
# 3     2004-11-30  [44.880001068115234, -0.8010769858956337]
# 4     2004-12-01    [44.93000030517578, 0.8925615362823012]
# ...          ...                                        ...
# 2911  2019-01-25   [122.27999877929688, 0.8107122350484133]
# 2912  2019-01-28   [120.95999908447266, 0.8944073989987373]
# 2913  2019-01-30  [121.16000366210938, -0.6877921521663666]
# 2914  2019-01-31    [122.0199966430664, 0.6936637610197068]
# 2915  2019-02-01               [122.75, 0.6690251007676125]
#
#                                        Target-2  \
# 0        [44.4900016784668, 0.7264769300818444]
# 1                   [44.75, 0.3478713557124139]
# 2     [44.880001068115234, -0.8010769858956337]
# 3       [44.93000030517578, 0.8925615362823012]
# 4      [45.099998474121094, 0.0849677324295044]
# ...                                         ...
# 2911   [120.95999908447266, 0.8944073989987373]
# 2912  [121.16000366210938, -0.6877921521663666]
# 2913    [122.0199966430664, 0.6936637610197068]
# 2914               [122.75, 0.6690251007676125]
# 2915   [123.91000366210938, 0.7154975235462189]
#
#                                         Target-1      Target
# 0                    [44.75, 0.3478713557124139]   44.880001
# 1      [44.880001068115234, -0.8010769858956337]   44.930000
# 2        [44.93000030517578, 0.8925615362823012]   45.099998
# 3       [45.099998474121094, 0.0849677324295044]   45.369999
# 4      [45.369998931884766, -0.8006784543395044]   45.279999
# ...                                          ...         ...
# 2911   [121.16000366210938, -0.6877921521663666]  122.019997
# 2912     [122.0199966430664, 0.6936637610197068]  122.750000
# 2913                [122.75, 0.6690251007676125]  123.910004
# 2914    [123.91000366210938, 0.7154975235462189]  125.180000
# 2915  [125.18000030517578, -0.26254571974277496]  124.889999
#
# [2916 rows x 5 columns]

# %%
df
# Out:
#                   Open  sentiment
# Date
# 2004-11-18   44.430000  -0.579322
# 2004-11-19   44.490002   0.726477
# 2004-11-22   44.750000   0.347871
# 2004-11-23   44.880001  -0.801077
# 2004-11-24   44.930000   0.892562
# ...                ...        ...
# 2019-01-25  122.019997   0.693664
# 2019-01-28  122.750000   0.669025
# 2019-01-30  123.910004   0.715498
# 2019-01-31  125.180000  -0.262546
# 2019-02-01  124.889999   0.044645
#
# [2919 rows x 2 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
    dates = windowed_dataframe["Target Date"].to_numpy()

    feature_cols = windowed_dataframe.columns[1:-1]

    X = []
    for _, row in windowed_dataframe[feature_cols].iterrows():
        # Each val is a [Close, Sentiment] pair
        values = [val for val in row]  # Keep as 2D structure
        X.append(values)

    X = np.array(X)  # Shape will be (num_rows, n, 2)
    Y = windowed_dataframe["Target"].to_numpy()

    return dates, X.astype(np.float32), Y.astype(np.float32)


dates, X, y = windowed_df_to_date_X_y(windowed_df)

# check all the shapes
dates.shape, X.shape, y.shape
# Out:
# ((2916,), (2916, 3, 2), (2916,))

# %%
# training part
q_75 = int(len(dates) * 0.75)

# validation part
q_85 = int(len(dates) * 0.85)

# testing part
q_95 = int(len(dates) * 0.95)

dates_train, X_train, y_train = dates[:q_75], X[:q_75], y[:q_75]
dates_val, X_val, y_val = dates[q_75:q_85], X[q_75:q_85], y[q_75:q_85]
dates_test, X_test, y_test = dates[q_85:q_95], X[q_85:q_95], y[q_85:q_95]
dates_hold, X_hold, y_hold = dates[q_95:], X[q_95:], y[q_95:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(["Train", "Validation", "Test"])
plt.xlabel("Date")
plt.ylabel("Target Value")
plt.title("Train / Validation / Test Split")
plt.show()

# %%
X_train
# Out:
# array([[[ 44.43      ,  -0.5793219 ],
#         [ 44.49      ,   0.7264769 ],
#         [ 44.75      ,   0.34787136]],
#
#        [[ 44.49      ,   0.7264769 ],
#         [ 44.75      ,   0.34787136],
#         [ 44.88      ,  -0.801077  ]],
#
#        [[ 44.75      ,   0.34787136],
#         [ 44.88      ,  -0.801077  ],
#         [ 44.93      ,   0.89256155]],
#
#        ...,
#
#        [[105.76      ,   0.5046343 ],
#         [106.32      ,   0.45507243],
#         [106.86      ,   0.57726234]],
#
#        [[106.32      ,   0.45507243],
#         [106.86      ,   0.57726234],
#         [106.55      ,  -0.29270324]],
#
#        [[106.86      ,   0.57726234],
#         [106.55      ,  -0.29270324],
#         [106.61      ,   0.37641606]]], dtype=float32)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential(
    [
        layers.Input((3, 2)),  # window size = 3, feature = 2
        layers.LSTM(64),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(1),
    ]
)  # since the output we want is just 1

model.compile(
    loss="mse", optimizer=Adam(learning_rate=0.001), metrics=["mean_absolute_error"]
)

model.fit(
    X_train, y_train, validation_data=(X_val, y_val), epochs=100
)  # 100 runs through the dataset
# Out:
# Epoch 1/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 12902.7061 - mean_absolute_error: 107.2586 - val_loss: 10146.1826 - val_mean_absolute_error: 100.5766
# Epoch 2/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6368.2275 - mean_absolute_error: 68.9484 - val_loss: 68.1528 - val_mean_absolute_error: 7.0600
# Epoch 3/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 645.7953 - mean_absolute_error: 18.6012 - val_loss: 3.2454 - val_mean_absolute_error: 1.3933
# Epoch 4/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 15.4613 - mean_absolute_error: 2.3597 - val_loss: 1.6069 - val_mean_absolute_error: 0.9358
# Epoch 5/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8662 - mean_absolute_error: 1.4285 - val_loss: 2.2116 - val_mean_absolute_error: 1.1593
# Epoch 6/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0284 - mean_absolute_error: 1.4222 - val_loss: 2.0111 - val_mean_absolute_error: 1.0864
# Epoch 7/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1740 - mean_absolute_error: 1.2651 - val_loss: 3.5027 - val_mean_absolute_error: 1.5710
# Epoch 8/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1138 - mean_absolute_error: 1.2860 - val_loss: 3.4270 - val_mean_absolute_error: 1.5356
# Epoch 9/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0170 - mean_absolute_error: 1.2453 - val_loss: 2.3456 - val_mean_absolute_error: 1.2092
# Epoch 10/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5264 - mean_absolute_error: 1.3880 - val_loss: 1.6849 - val_mean_absolute_error: 0.9968
# Epoch 11/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7295 - mean_absolute_error: 1.1905 - val_loss: 1.7826 - val_mean_absolute_error: 1.0227
# Epoch 12/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8919 - mean_absolute_error: 1.2218 - val_loss: 3.4782 - val_mean_absolute_error: 1.5649
# Epoch 13/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6932 - mean_absolute_error: 1.2124 - val_loss: 1.5390 - val_mean_absolute_error: 0.9014
# Epoch 14/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6851 - mean_absolute_error: 1.2192 - val_loss: 1.4841 - val_mean_absolute_error: 0.8802
# Epoch 15/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0925 - mean_absolute_error: 1.3002 - val_loss: 2.0203 - val_mean_absolute_error: 1.0937
# Epoch 16/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7860 - mean_absolute_error: 1.2037 - val_loss: 1.4170 - val_mean_absolute_error: 0.8797
# Epoch 17/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6783 - mean_absolute_error: 1.1760 - val_loss: 1.4305 - val_mean_absolute_error: 0.8851
# Epoch 18/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6786 - mean_absolute_error: 1.1797 - val_loss: 1.4122 - val_mean_absolute_error: 0.8689
# Epoch 19/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2196 - mean_absolute_error: 1.3168 - val_loss: 1.8538 - val_mean_absolute_error: 1.0360
# Epoch 20/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0499 - mean_absolute_error: 1.2870 - val_loss: 1.5763 - val_mean_absolute_error: 0.9487
# Epoch 21/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9887 - mean_absolute_error: 1.2479 - val_loss: 2.2456 - val_mean_absolute_error: 1.1786
# Epoch 22/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1703 - mean_absolute_error: 1.3388 - val_loss: 1.5967 - val_mean_absolute_error: 0.9291
# Epoch 23/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6303 - mean_absolute_error: 1.1709 - val_loss: 2.2896 - val_mean_absolute_error: 1.1931
# Epoch 24/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8790 - mean_absolute_error: 1.2330 - val_loss: 1.8308 - val_mean_absolute_error: 1.0293
# Epoch 25/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7515 - mean_absolute_error: 1.2128 - val_loss: 2.5796 - val_mean_absolute_error: 1.2889
# Epoch 26/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4631 - mean_absolute_error: 1.3291 - val_loss: 1.5692 - val_mean_absolute_error: 0.9497
# Epoch 27/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6367 - mean_absolute_error: 1.2101 - val_loss: 1.8319 - val_mean_absolute_error: 1.0131
# Epoch 28/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5347 - mean_absolute_error: 1.1623 - val_loss: 1.5368 - val_mean_absolute_error: 0.9200
# Epoch 29/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4685 - mean_absolute_error: 1.1699 - val_loss: 1.4184 - val_mean_absolute_error: 0.8729
# Epoch 30/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1333 - mean_absolute_error: 1.3037 - val_loss: 1.9192 - val_mean_absolute_error: 1.0549
# Epoch 31/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6165 - mean_absolute_error: 1.1979 - val_loss: 1.5696 - val_mean_absolute_error: 0.9336
# Epoch 32/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5522 - mean_absolute_error: 1.1566 - val_loss: 4.4674 - val_mean_absolute_error: 1.8563
# Epoch 33/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0327 - mean_absolute_error: 1.2739 - val_loss: 1.4291 - val_mean_absolute_error: 0.8833
# Epoch 34/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6195 - mean_absolute_error: 1.3527 - val_loss: 1.8279 - val_mean_absolute_error: 1.0559
# Epoch 35/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8683 - mean_absolute_error: 1.2380 - val_loss: 1.6310 - val_mean_absolute_error: 0.9783
# Epoch 36/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1968 - mean_absolute_error: 1.2618 - val_loss: 1.5342 - val_mean_absolute_error: 0.9197
# Epoch 37/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4698 - mean_absolute_error: 1.1434 - val_loss: 1.4493 - val_mean_absolute_error: 0.8942
# Epoch 38/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6603 - mean_absolute_error: 1.1809 - val_loss: 1.4669 - val_mean_absolute_error: 0.8986
# Epoch 39/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2323 - mean_absolute_error: 1.3666 - val_loss: 1.7667 - val_mean_absolute_error: 1.0347
# Epoch 40/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5794 - mean_absolute_error: 1.1567 - val_loss: 1.5278 - val_mean_absolute_error: 0.9312
# Epoch 41/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1676 - mean_absolute_error: 1.3091 - val_loss: 1.4482 - val_mean_absolute_error: 0.8845
# Epoch 42/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6830 - mean_absolute_error: 1.1871 - val_loss: 2.4488 - val_mean_absolute_error: 1.2388
# Epoch 43/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9778 - mean_absolute_error: 1.2778 - val_loss: 1.6803 - val_mean_absolute_error: 0.9921
# Epoch 44/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6855 - mean_absolute_error: 1.1957 - val_loss: 1.4731 - val_mean_absolute_error: 0.8913
# Epoch 45/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6259 - mean_absolute_error: 1.1490 - val_loss: 1.8837 - val_mean_absolute_error: 1.0454
# Epoch 46/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4910 - mean_absolute_error: 1.1495 - val_loss: 1.9462 - val_mean_absolute_error: 1.1027
# Epoch 47/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7526 - mean_absolute_error: 1.1830 - val_loss: 1.4376 - val_mean_absolute_error: 0.8857
# Epoch 48/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6704 - mean_absolute_error: 1.1492 - val_loss: 1.5472 - val_mean_absolute_error: 0.9173
# Epoch 49/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9916 - mean_absolute_error: 1.2747 - val_loss: 1.7575 - val_mean_absolute_error: 0.9922
# Epoch 50/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5550 - mean_absolute_error: 1.1579 - val_loss: 1.9183 - val_mean_absolute_error: 1.0878
# Epoch 51/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8942 - mean_absolute_error: 1.2474 - val_loss: 1.4657 - val_mean_absolute_error: 0.9039
# Epoch 52/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9659 - mean_absolute_error: 1.2633 - val_loss: 1.7213 - val_mean_absolute_error: 1.0123
# Epoch 53/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6049 - mean_absolute_error: 1.4148 - val_loss: 4.5004 - val_mean_absolute_error: 1.8209
# Epoch 54/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8484 - mean_absolute_error: 1.2351 - val_loss: 1.4901 - val_mean_absolute_error: 0.9183
# Epoch 55/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7391 - mean_absolute_error: 1.1853 - val_loss: 3.4119 - val_mean_absolute_error: 1.5761
# Epoch 56/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0184 - mean_absolute_error: 1.2643 - val_loss: 1.5711 - val_mean_absolute_error: 0.9512
# Epoch 57/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4324 - mean_absolute_error: 1.1513 - val_loss: 1.4583 - val_mean_absolute_error: 0.9011
# Epoch 58/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4653 - mean_absolute_error: 1.1647 - val_loss: 1.9768 - val_mean_absolute_error: 1.0854
# Epoch 59/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6341 - mean_absolute_error: 1.1719 - val_loss: 1.5243 - val_mean_absolute_error: 0.9318
# Epoch 60/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4948 - mean_absolute_error: 1.1283 - val_loss: 1.7872 - val_mean_absolute_error: 0.9945
# Epoch 61/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9502 - mean_absolute_error: 1.2292 - val_loss: 2.9823 - val_mean_absolute_error: 1.4039
# Epoch 62/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5052 - mean_absolute_error: 1.4012 - val_loss: 2.7671 - val_mean_absolute_error: 1.3385
# Epoch 63/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6408 - mean_absolute_error: 1.1608 - val_loss: 1.5494 - val_mean_absolute_error: 0.9443
# Epoch 64/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9685 - mean_absolute_error: 1.2692 - val_loss: 1.4862 - val_mean_absolute_error: 0.8942
# Epoch 65/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9178 - mean_absolute_error: 1.2264 - val_loss: 1.8934 - val_mean_absolute_error: 1.0613
# Epoch 66/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9767 - mean_absolute_error: 1.2663 - val_loss: 1.5233 - val_mean_absolute_error: 0.9161
# Epoch 67/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3283 - mean_absolute_error: 1.1021 - val_loss: 1.5147 - val_mean_absolute_error: 0.9244
# Epoch 68/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7526 - mean_absolute_error: 1.1935 - val_loss: 1.6409 - val_mean_absolute_error: 0.9785
# Epoch 69/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6015 - mean_absolute_error: 1.1833 - val_loss: 4.1271 - val_mean_absolute_error: 1.7163
# Epoch 70/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1407 - mean_absolute_error: 1.3686 - val_loss: 3.2233 - val_mean_absolute_error: 1.4756
# Epoch 71/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6068 - mean_absolute_error: 1.1895 - val_loss: 1.5155 - val_mean_absolute_error: 0.9245
# Epoch 72/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7787 - mean_absolute_error: 1.2152 - val_loss: 3.1703 - val_mean_absolute_error: 1.4993
# Epoch 73/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6608 - mean_absolute_error: 1.3559 - val_loss: 5.1349 - val_mean_absolute_error: 1.9747
# Epoch 74/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8441 - mean_absolute_error: 1.2485 - val_loss: 1.4457 - val_mean_absolute_error: 0.8941
# Epoch 75/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6585 - mean_absolute_error: 1.1919 - val_loss: 1.4704 - val_mean_absolute_error: 0.8925
# Epoch 76/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5745 - mean_absolute_error: 1.1786 - val_loss: 1.6806 - val_mean_absolute_error: 0.9639
# Epoch 77/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7030 - mean_absolute_error: 1.2204 - val_loss: 1.5044 - val_mean_absolute_error: 0.9033
# Epoch 78/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9782 - mean_absolute_error: 1.2540 - val_loss: 1.6155 - val_mean_absolute_error: 0.9723
# Epoch 79/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6380 - mean_absolute_error: 1.2037 - val_loss: 1.4625 - val_mean_absolute_error: 0.9038
# Epoch 80/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5502 - mean_absolute_error: 1.1601 - val_loss: 1.6467 - val_mean_absolute_error: 0.9548
# Epoch 81/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7402 - mean_absolute_error: 1.2082 - val_loss: 1.6639 - val_mean_absolute_error: 0.9915
# Epoch 82/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7312 - mean_absolute_error: 1.1939 - val_loss: 1.9518 - val_mean_absolute_error: 1.0600
# Epoch 83/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8710 - mean_absolute_error: 1.2422 - val_loss: 1.5278 - val_mean_absolute_error: 0.9307
# Epoch 84/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3260 - mean_absolute_error: 1.1090 - val_loss: 1.8310 - val_mean_absolute_error: 1.0149
# Epoch 85/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6933 - mean_absolute_error: 1.1970 - val_loss: 1.8328 - val_mean_absolute_error: 1.0497
# Epoch 86/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0659 - mean_absolute_error: 1.2507 - val_loss: 1.4357 - val_mean_absolute_error: 0.8876
# Epoch 87/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8655 - mean_absolute_error: 1.2044 - val_loss: 1.7597 - val_mean_absolute_error: 0.9974
# Epoch 88/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4595 - mean_absolute_error: 1.3901 - val_loss: 2.7349 - val_mean_absolute_error: 1.3690
# Epoch 89/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7645 - mean_absolute_error: 1.2471 - val_loss: 1.9572 - val_mean_absolute_error: 1.0654
# Epoch 90/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3714 - mean_absolute_error: 1.1347 - val_loss: 1.9568 - val_mean_absolute_error: 1.0933
# Epoch 91/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0436 - mean_absolute_error: 1.2862 - val_loss: 1.6353 - val_mean_absolute_error: 0.9491
# Epoch 92/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7320 - mean_absolute_error: 1.1800 - val_loss: 4.1405 - val_mean_absolute_error: 1.7773
# Epoch 93/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7644 - mean_absolute_error: 1.2540 - val_loss: 2.4755 - val_mean_absolute_error: 1.2458
# Epoch 94/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3368 - mean_absolute_error: 1.3000 - val_loss: 1.4368 - val_mean_absolute_error: 0.8889
# Epoch 95/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7126 - mean_absolute_error: 1.1475 - val_loss: 1.4672 - val_mean_absolute_error: 0.8963
# Epoch 96/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5043 - mean_absolute_error: 1.1279 - val_loss: 1.5476 - val_mean_absolute_error: 0.9431
# Epoch 97/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5514 - mean_absolute_error: 1.1496 - val_loss: 1.7782 - val_mean_absolute_error: 1.0049
# Epoch 98/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9299 - mean_absolute_error: 1.2416 - val_loss: 3.6454 - val_mean_absolute_error: 1.5909
# Epoch 99/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1108 - mean_absolute_error: 1.3016 - val_loss: 1.9567 - val_mean_absolute_error: 1.0992
# Epoch 100/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5826 - mean_absolute_error: 1.1631 - val_loss: 1.4897 - val_mean_absolute_error: 0.9162

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(["Training Predictions", "Training Observations"])
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score,
    mean_absolute_percentage_error,
    explained_variance_score,
)
import numpy as np

mae = mean_absolute_error(y_train, train_predictions)
mse = mean_squared_error(y_train, train_predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_train, train_predictions)
mape = mean_absolute_percentage_error(y_train, train_predictions)
explained_var = explained_variance_score(y_train, train_predictions)

print(f"MAE: {mae:.4f}")
print(f"MSE: {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"R² Score: {r2:.4f}")
print(f"MAPE: {mape:.4f}")
print(f"Explained Variance: {explained_var:.4f}")
# Out:
# MAE: 1.0601
# MSE: 2.2869
# RMSE: 1.5122
# R² Score: 0.9984
# MAPE: 0.0100
# Explained Variance: 0.9984

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(["Validation Predictions", "Validation Observations"])
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
mae = mean_absolute_error(y_val, val_predictions)
mse = mean_squared_error(y_val, val_predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_val, val_predictions)
mape = mean_absolute_percentage_error(y_val, val_predictions)
explained_var = explained_variance_score(y_val, val_predictions)

print(f"MAE: {mae:.4f}")
print(f"MSE: {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"R² Score: {r2:.4f}")
print(f"MAPE: {mape:.4f}")
print(f"Explained Variance: {explained_var:.4f}")
# Out:
# MAE: 0.9162
# MSE: 1.4897
# RMSE: 1.2205
# R² Score: 0.9497
# MAPE: 0.0077
# Explained Variance: 0.9516

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(["Testing Predictions", "Testing Observations"])
plt.xlabel("Year-Month")  # x-axis label
plt.ylabel("Open Price")  # y-axis label
plt.title("Testing Predictions vs Observations")
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# your data
# dates_test, y_test, test_predictions
test_predictions = model.predict(X_test).flatten()

fig, ax = plt.subplots(figsize=(12, 6))

# force a white background
fig.patch.set_facecolor("white")
ax.set_facecolor("white")

# plot the actuals
ax.plot(
    dates_test, y_test, label="Testing Observations", color="tab:blue", linewidth=1.5
)

# plot the preds
ax.plot(
    dates_test,
    test_predictions,
    label="Testing Predictions",
    color="tab:orange",
    linestyle="--",
    linewidth=1.5,
)

# labels & title
ax.set_xlabel("Year-Month")
ax.set_ylabel("Open Price")
ax.set_title("Testing Predictions vs Observations", pad=12)

# legend
ax.legend(loc="upper left")

# dashed grid
ax.grid(True, which="major", linestyle="--", linewidth=0.5, alpha=0.7)

# nice date formatting
# choose a locator (e.g. every 3 months) or leave default
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))

# format as YYYY-MM
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))

# rotate if needed
fig.autofmt_xdate()

plt.tight_layout()
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
# y_test and test_predictions should be 1D arrays or Series
mae = mean_absolute_error(y_test, test_predictions)

# MAE % relative to the mean of actuals
mae_pct = mae / np.mean(y_test) * 100

# Directional Accuracy: how often the model gets the up/down move right
actual_dir = np.sign(np.diff(y_test))
pred_dir = np.sign(np.diff(test_predictions))
directional_accuracy = np.mean(actual_dir == pred_dir)

# R² score
r2 = r2_score(y_test, test_predictions)

# print them out
print(f"MAE: {mae:.4f}")
print(f"MAE %: {mae_pct:.2f}%")
print(f"Directional Accuracy: {directional_accuracy:.4f}")
print(f"R² Score: {r2:.4f}")
# Out:
# MAE: 0.6003
# MAE %: 0.49%
# Directional Accuracy: 0.5120
# R² Score: 0.9393

# %%
mae = mean_absolute_error(y_test, test_predictions)
mse = mean_squared_error(y_test, test_predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, test_predictions)
mape = mean_absolute_percentage_error(y_test, test_predictions)
explained_var = explained_variance_score(y_test, test_predictions)

print(f"MAE: {mae:.4f}")
print(f"MSE: {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"R² Score: {r2:.4f}")
print(f"MAPE: {mape:.4f}")
print(f"Explained Variance: {explained_var:.4f}")
# Out:
# MAE: 0.6003
# MSE: 0.6050
# RMSE: 0.7778
# R² Score: 0.9393
# MAPE: 0.0049
# Explained Variance: 0.9421

# %%
directional_accuracy
# Out:
# 0.5120274914089347
